# %%
numbers = [10, 20, 30, 40, 50]

print(numbers)

# %%
numbers = [10, 20, 30, 40, 50]

print("Original List", numbers)

numbers.append(60)

print("After appending", numbers)

# %%
numbers = [10, 20, 30, 40, 50]

print("Original List", numbers)

numbers.reverse()

print("After appending", numbers)
# Out:
# Original List [10, 20, 30, 40, 50]
# After appending [50, 40, 30, 20, 10]

# %%
numbers = [10, 20, 10, 30, 10, 40, 50]
element = int(input("Enter the elements to search"))
count = numbers.count(element)
print(f"Number of occurances of {element} are {count}")
# Out:
# Enter the elements to search 10
# Number of occurances of 10 are 3

# %%
list1 = [10, 20, 30]
list2 = [40, 50, 60]

list1=list1+list2
print(list1)
print(list2)
# Out:
# [10, 20, 30, 40, 50, 60]
# [40, 50, 60]

# %%
numbers = [10, 20, 30, 40, 50]

print("Original List:", numbers)

numbers.insert(1, 15)

print("After inserting:", numbers)
# Out:
# Original List: [10, 20, 30, 40, 50]
# After inserting: [10, 15, 20, 30, 40, 50]

# %%
numbers = [10, 20, 30, 40, 50]

index = int(input("Enter the index to remove(pop):"))

print("Original List:", numbers)

numbers.pop(index)

print("After poping:", numbers)

# %%
numbers = [10, 20, 30, 40, 50]

element = int(input("Enter the element to remove:"))

print("Original List:", numbers)

numbers.remove(element)

print("After removing:", numbers)
# Out:
# Enter the element to remove: 20
# Original List: [10, 20, 30, 40, 50]
# After removing: [10, 30, 40, 50]
